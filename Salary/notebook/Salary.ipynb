# %% [markdown]
# # Calculating Employee Salaries using Multiple Linear Regression

# %% [markdown]
# The Data talks about the salaries of employees Depending two attributes of age and experience

# %% [markdown]
# # 1 - first step import library

# %% [markdown]
# import model LinearRegression and pandas to read csv file and numpy to math operation

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math

# %% [markdown]
# ## 2 - Read File

# %%
dataset=pd.read_csv(r'D:\Projects\projects\Machine-learning-algorithms\Salary\data\multiple_linear_regression_dataset.csv')

# %% [markdown]
# ## 3 - Data analysis

# %% [markdown]
# info to know more information about Data

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         20 non-null     int64
#  1   experience  20 non-null     int64
#  2   income      20 non-null     int64
# dtypes: int64(3)
# memory usage: 612.0 bytes

# %% [markdown]
# shape to know the how many Row and Columns in Data

# %%
dataset.shape
# Out:
# (20, 3)

# %% [markdown]
# sample to Display random Data I say 7 Row

# %%
dataset.sample(7)
# Out:
#     age  experience  income
# 5    51           7   41630
# 18   44           9   44190
# 14   44          12   51300
# 4    43          10   47830
# 10   29           1   27840
# 7    33           4   37650
# 1    30           3   35670

# %% [markdown]
# value_counts to know The columns value and how many count

# %%
dataset['age'].value_counts()
# Out:
# age
# 47    2
# 51    2
# 44    2
# 37    2
# 32    1
# 43    1
# 30    1
# 25    1
# 33    1
# 28    1
# 29    1
# 39    1
# 54    1
# 41    1
# 58    1
# 23    1
# Name: count, dtype: int64

# %%
dataset['experience'].value_counts()
# Out:
# experience
# 5     4
# 1     3
# 4     2
# 10    2
# 9     2
# 3     1
# 2     1
# 7     1
# 8     1
# 12    1
# 6     1
# 17    1
# Name: count, dtype: int64

# %% [markdown]
# min : to know the smale value in Columns
# max : to know the big value in Columns

# %%
np.min(dataset['age']),np.max(dataset['age'])
# Out:
# (np.int64(23), np.int64(58))

# %%
np.min(dataset['experience']),np.max(dataset['experience'])
# Out:
# (np.int64(1), np.int64(17))

# %% [markdown]
# ## 4 - Determine Feature (X) and Target (y)

# %%
X=dataset[['age','experience']]
y=dataset['income']

# %% [markdown]
# head to display 5 Row

# %%
X.head()
# Out:
#    age  experience
# 0   25           1
# 1   30           3
# 2   47           2
# 3   32           5
# 4   43          10

# %%
y.head()
# Out:
# 0    30450
# 1    35670
# 2    31580
# 3    40130
# 4    47830
# Name: income, dtype: int64

# %%
plt.scatter(dataset['experience'],dataset['income'])
plt.xlabel('Experience level')
plt.ylabel('income')
plt.show()

# %% [markdown]
# ## 5 - Traning The Model

# %%
reg_model=LinearRegression()
reg_model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## 6 - Evaluation the model

# %%
reg_model.score(X,y)
# Out:
# 0.9773361310180797

# %%
reg_model.coef_,reg_model.intercept_
# Out:
# (array([ -99.19535546, 2162.40419192]), np.float64(31261.68985410128))

# %% [markdown]
# ## 7 - Predict New Data

# %% [markdown]
# predict emply have 50 age and 10 experience

# %%
y_predict=reg_model.predict([[50,10]])
print(np.ceil(y_predict))
# Out:
# [47926.]
# C:\Users\sjama\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
